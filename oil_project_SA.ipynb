# %% [markdown]
# ### Investigating Oil Price fluctuations on the Saudi Arabian economy

# %%
import numpy as np 
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.ardl import ardl_select_order
from statsmodels.tsa.ardl import ARDL
import math
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Parse the XML file
tree = ET.parse('opec_daily.xml')
root = tree.getroot()
namespace = {'ns': 'http://tempuri.org/basketDayArchives.xsd'}

# Initialize lists to store the data
dates = []
values = []

# Loop through and extract the date (data) and price (val)
for basket in root.findall('ns:BasketList', namespace): 
    date = basket.get('data') 
    value = basket.get('val')  
    
    # Append the values to the lists
    dates.append(date)
    values.append(float(value))  # Convert to float for numeric operations

# Create a pandas DataFrame
opec = pd.DataFrame({'Date': dates, 'Oil_Price': values})

# Convert 'Date' to a pandas datetime format
opec['Date'] = pd.to_datetime(opec['Date'])

# Display the DataFrame
print(opec.head())
# Out:
#         Date  Oil_Price
# 0 2003-01-02      30.05
# 1 2003-01-03      30.83
# 2 2003-01-06      30.71
# 3 2003-01-07      29.72
# 4 2003-01-08      28.86

# %%
opec.to_csv('oil_prices.csv', index=False)

# %%
opec = pd.read_csv('oil_prices.csv')

# %%
opec['Date'] = pd.to_datetime(opec['Date'])
opec.set_index('Date', inplace=True)
q_opec = opec.resample('QE').mean()
q_opec = q_opec.loc['2010-01-01':'2023-09-30']
q_opec.reset_index(inplace=True)
q_opec['Quarter'] = q_opec['Date'].dt.to_period('Q')
q_opec.head()
# Out:
#         Date   Oil_Price Quarter
# 0 2010-03-31   75.490476  2010Q1
# 1 2010-06-30   76.530937  2010Q2
# 2 2010-09-30   73.764545  2010Q3
# 3 2010-12-31   83.881061  2010Q4
# 4 2011-03-31  101.270781  2011Q1

# %%
core_data = pd.read_csv("core_data.csv")
core_data['Quarter'] = pd.PeriodIndex(core_data['Date'], freq='Q')
core_data['Quarter_Start_Date'] = core_data['Quarter'].dt.start_time
core_data.head()
# Out:
#       Date  Gross Domestic Product  GDP Oil Activities  \
# 0  2010-Q1               480428.86           201371.13
# 1  2010-Q2               477912.07           212310.07
# 2  2010-Q3               479432.42           210994.12
# 3  2010-Q4               543004.01           250929.96
# 4  2011-Q1               603134.11           283149.93
#
#    GDP Non-Oil Activities observation_date  exports_percent_gdp      Exports  \
# 0               208194.93       01/01/2010            45.398501  21810749.91
# 1               199158.91       01/04/2010            47.999415  22939499.88
# 2               204003.49       01/07/2010            47.232413  22644749.98
# 3               198283.07       01/10/2010            49.324221  26783249.77
# 4               240588.73       01/01/2011            50.555920  30492000.06
#
#          CPI Quarter Quarter_Start_Date
# 0  80.878583  2010Q1         2010-01-01
# 1  81.904799  2010Q2         2010-04-01
# 2  83.448397  2010Q3         2010-07-01
# 3  84.534475  2010Q4         2010-10-01
# 4  86.538667  2011Q1         2011-01-01

# %%
reer = pd.read_csv("reer_r.csv")

# %%
reer['date'] = pd.to_datetime(reer['date'])
reer.set_index('date', inplace=True)
reer = reer.resample('QE').mean()
reer = reer.reset_index()
reer['Quarter'] = reer['date'].dt.to_period('Q')
reer = reer.head(-4)
reer.head()
# Out:
#         date       REER Quarter
# 0 2010-03-31  84.770000  2010Q1
# 1 2010-06-30  87.746667  2010Q2
# 2 2010-09-30  87.710000  2010Q3
# 3 2010-12-31  85.020000  2010Q4
# 4 2011-03-31  85.130000  2011Q1

# %%
total_exports = pd.read_csv('total_exports_only.csv')

# %%
# Ensuring the dataframes are the same length (use same dates)
print(len(reer))
print(len(core_data))
print(len(q_opec))
print(len(total_exports))
# Out:
# 55
# 55
# 55
# 55

# %%
varz = pd.DataFrame(data = { 'Quarter': reer['Quarter'], 'REER': reer["REER"], "GDP": core_data['Gross Domestic Product'], 'GDP Non-Oil' : core_data['GDP Non-Oil Activities'],
                            'GDP Oil': core_data['GDP Oil Activities'], 'CPI': core_data['CPI'], 'OPEC' : q_opec['Oil_Price'], 'Exports': total_exports['Total_Exports']})

# %%
varz.head()
# Out:
#   Quarter       REER        GDP  GDP Non-Oil    GDP Oil        CPI  \
# 0  2010Q1  84.770000  480428.86    208194.93  201371.13  80.878583
# 1  2010Q2  87.746667  477912.07    199158.91  212310.07  81.904799
# 2  2010Q3  87.710000  479432.42    204003.49  210994.12  83.448397
# 3  2010Q4  85.020000  543004.01    198283.07  250929.96  84.534475
# 4  2011Q1  85.130000  603134.11    240588.73  283149.93  86.538667
#
#          OPEC   Exports
# 0   75.490476  225340.0
# 1   76.530937  237786.0
# 2   73.764545  236480.0
# 3   83.881061  282260.0
# 4  101.270781  246709.6

# %%
dfcorr = varz[['REER', 'GDP', 'GDP Non-Oil', 'GDP Oil', 'CPI', 'OPEC', 'Exports']].corr()
dfcorr.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_b3983_row0_col0, #T_b3983_row1_col1, #T_b3983_row2_col2, #T_b3983_row3_col3, #T_b3983_row4_col4, #T_b3983_row5_col5, #T_b3983_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b3983_row0_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b3983_row0_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_b3983_row0_col3, #T_b3983_row0_col5, #T_b3983_row5_col0, #T_b3983_row5_col1, #T_b3983_row5_col2, #T_b3983_row5_col4, #T_b3983_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b3983_row0_col4 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_b3983_row0_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_b3983_row1_col0, #T_b3983_row1_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b3983_row1_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_b3983_row1_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_b3983_row1_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_b3983_row1_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_b3983_row2_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_b3983_row2_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_b3983_row2_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b3983_row2_col4 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b3983_row2_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b3983_row2_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b3983_row3_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b3983_row3_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b3983_row3_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b3983_row3_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b3983_row3_col5 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_b3983_row3_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b3983_row4_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_b3983_row4_col1 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_b3983_row4_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_b3983_row4_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b3983_row4_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_b3983_row4_col6 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_b3983_row5_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_b3983_row6_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_b3983_row6_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b3983_row6_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_b3983_row6_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b3983_row6_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b3983_row6_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_b3983">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3983_level0_col0" class="col_heading level0 col0" >REER</th>
#       <th id="T_b3983_level0_col1" class="col_heading level0 col1" >GDP</th>
#       <th id="T_b3983_level0_col2" class="col_heading level0 col2" >GDP Non-Oil</th>
#       <th id="T_b3983_level0_col3" class="col_heading level0 col3" >GDP Oil</th>
#       <th id="T_b3983_level0_col4" class="col_heading level0 col4" >CPI</th>
#       <th id="T_b3983_level0_col5" class="col_heading level0 col5" >OPEC</th>
#       <th id="T_b3983_level0_col6" class="col_heading level0 col6" >Exports</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3983_level0_row0" class="row_heading level0 row0" >REER</th>
#       <td id="T_b3983_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_b3983_row0_col1" class="data row0 col1" >0.50</td>
#       <td id="T_b3983_row0_col2" class="data row0 col2" >0.88</td>
#       <td id="T_b3983_row0_col3" class="data row0 col3" >-0.34</td>
#       <td id="T_b3983_row0_col4" class="data row0 col4" >0.86</td>
#       <td id="T_b3983_row0_col5" class="data row0 col5" >-0.66</td>
#       <td id="T_b3983_row0_col6" class="data row0 col6" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_b3983_level0_row1" class="row_heading level0 row1" >GDP</th>
#       <td id="T_b3983_row1_col0" class="data row1 col0" >0.50</td>
#       <td id="T_b3983_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_b3983_row1_col2" class="data row1 col2" >0.81</td>
#       <td id="T_b3983_row1_col3" class="data row1 col3" >0.60</td>
#       <td id="T_b3983_row1_col4" class="data row1 col4" >0.80</td>
#       <td id="T_b3983_row1_col5" class="data row1 col5" >0.27</td>
#       <td id="T_b3983_row1_col6" class="data row1 col6" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_b3983_level0_row2" class="row_heading level0 row2" >GDP Non-Oil</th>
#       <td id="T_b3983_row2_col0" class="data row2 col0" >0.88</td>
#       <td id="T_b3983_row2_col1" class="data row2 col1" >0.81</td>
#       <td id="T_b3983_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_b3983_row2_col3" class="data row2 col3" >0.02</td>
#       <td id="T_b3983_row2_col4" class="data row2 col4" >0.97</td>
#       <td id="T_b3983_row2_col5" class="data row2 col5" >-0.32</td>
#       <td id="T_b3983_row2_col6" class="data row2 col6" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_b3983_level0_row3" class="row_heading level0 row3" >GDP Oil</th>
#       <td id="T_b3983_row3_col0" class="data row3 col0" >-0.34</td>
#       <td id="T_b3983_row3_col1" class="data row3 col1" >0.60</td>
#       <td id="T_b3983_row3_col2" class="data row3 col2" >0.02</td>
#       <td id="T_b3983_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_b3983_row3_col4" class="data row3 col4" >0.04</td>
#       <td id="T_b3983_row3_col5" class="data row3 col5" >0.92</td>
#       <td id="T_b3983_row3_col6" class="data row3 col6" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_b3983_level0_row4" class="row_heading level0 row4" >CPI</th>
#       <td id="T_b3983_row4_col0" class="data row4 col0" >0.86</td>
#       <td id="T_b3983_row4_col1" class="data row4 col1" >0.80</td>
#       <td id="T_b3983_row4_col2" class="data row4 col2" >0.97</td>
#       <td id="T_b3983_row4_col3" class="data row4 col3" >0.04</td>
#       <td id="T_b3983_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_b3983_row4_col5" class="data row4 col5" >-0.28</td>
#       <td id="T_b3983_row4_col6" class="data row4 col6" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_b3983_level0_row5" class="row_heading level0 row5" >OPEC</th>
#       <td id="T_b3983_row5_col0" class="data row5 col0" >-0.66</td>
#       <td id="T_b3983_row5_col1" class="data row5 col1" >0.27</td>
#       <td id="T_b3983_row5_col2" class="data row5 col2" >-0.32</td>
#       <td id="T_b3983_row5_col3" class="data row5 col3" >0.92</td>
#       <td id="T_b3983_row5_col4" class="data row5 col4" >-0.28</td>
#       <td id="T_b3983_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_b3983_row5_col6" class="data row5 col6" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_b3983_level0_row6" class="row_heading level0 row6" >Exports</th>
#       <td id="T_b3983_row6_col0" class="data row6 col0" >0.42</td>
#       <td id="T_b3983_row6_col1" class="data row6 col1" >0.53</td>
#       <td id="T_b3983_row6_col2" class="data row6 col2" >0.48</td>
#       <td id="T_b3983_row6_col3" class="data row6 col3" >0.29</td>
#       <td id="T_b3983_row6_col4" class="data row6 col4" >0.44</td>
#       <td id="T_b3983_row6_col5" class="data row6 col5" >0.01</td>
#       <td id="T_b3983_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Need to convert nominal prices to real

# %%
varz_re = varz[['Quarter', 'GDP', 'GDP Non-Oil', 'GDP Oil', 'REER', 'CPI', 'OPEC', 'Exports']]
varz_re['GDP'] = 109.501439 * varz['GDP'] / varz['CPI']
varz_re['GDP Non-Oil'] = 109.501439 * varz['GDP Non-Oil'] / varz['CPI']
varz_re['GDP Oil'] = 109.501439 * varz['GDP Oil'] / varz['CPI']
varz_re['OPEC'] = 109.501439 * varz['OPEC'] / varz['CPI']
varz_re.head()
# Out:
#   Quarter            GDP    GDP Non-Oil        GDP Oil       REER        CPI  \
# 0  2010Q1  650452.188140  281874.922706  272636.186212  84.770000  80.878583
# 1  2010Q2  638937.648740  266262.632122  283844.885796  87.746667  81.904799
# 2  2010Q3  629113.819797  267694.485170  276867.627742  87.710000  83.448397
# 3  2010Q4  703378.361966  256845.287353  325041.253808  85.020000  84.534475
# 4  2011Q1  763173.914001  304428.218690  358282.903826  85.130000  86.538667
#
#          OPEC   Exports
# 0  102.206486  225340.0
# 1  102.316933  237786.0
# 2   96.794236  236480.0
# 3  108.655041  282260.0
# 4  128.142675  246709.6

# %% [markdown]
# Then remove the seasonality

# %%
varz_ds = pd.DataFrame()
varz_ds['Quarter'] = varz['Quarter']

columns_to_ds = ['GDP', 'GDP Non-Oil', 'GDP Oil', 'REER', 'CPI', 'OPEC', 'Exports']

for col in columns_to_ds:
    result = seasonal_decompose(varz_re[col], model='additive', period=4)  
    varz_ds[col] = varz_re[col] - result.seasonal
    
#varz_ds.index = varz.index

varz_ds.head()
# Out:
#   Quarter            GDP    GDP Non-Oil        GDP Oil       REER        CPI  \
# 0  2010Q1  648224.248621  270740.787008  280820.127266  84.910097  80.807196
# 1  2010Q2  638209.329087  273623.489461  278404.643673  88.136985  82.075866
# 2  2010Q3  632283.555277  268249.783939  274238.791330  87.349167  83.255991
# 3  2010Q4  703164.885657  260063.266943  324926.391289  84.850417  84.627201
# 4  2011Q1  760945.974482  293294.082992  366466.844880  85.270097  86.467279
#
#          OPEC        Exports
# 0  102.583773  233321.241927
# 1  100.753092  242658.369411
# 2   96.458066  248071.761158
# 3  110.177765  257814.627504
# 4  128.519963  254690.841927

# %%
dfcorrds = varz_ds[['REER', 'GDP', 'GDP Non-Oil', 'GDP Oil', 'CPI', 'OPEC', 'Exports']].corr()
dfcorrds.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_7409e_row0_col0, #T_7409e_row1_col1, #T_7409e_row2_col2, #T_7409e_row3_col3, #T_7409e_row4_col4, #T_7409e_row5_col5, #T_7409e_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7409e_row0_col1, #T_7409e_row0_col3, #T_7409e_row0_col5, #T_7409e_row5_col0, #T_7409e_row5_col2, #T_7409e_row5_col4, #T_7409e_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7409e_row0_col2 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_7409e_row0_col4 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_7409e_row0_col6 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_7409e_row1_col0, #T_7409e_row4_col6 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_7409e_row1_col2, #T_7409e_row1_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_7409e_row1_col3, #T_7409e_row6_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_7409e_row1_col5 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_7409e_row1_col6, #T_7409e_row2_col6 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_7409e_row2_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_7409e_row2_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_7409e_row2_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7409e_row2_col4, #T_7409e_row5_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_7409e_row2_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7409e_row3_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_7409e_row3_col1, #T_7409e_row6_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_7409e_row3_col2, #T_7409e_row3_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_7409e_row3_col5, #T_7409e_row4_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_7409e_row3_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_7409e_row4_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_7409e_row4_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7409e_row4_col3 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_7409e_row4_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7409e_row5_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_7409e_row6_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_7409e_row6_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_7409e_row6_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_7409e_row6_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# </style>
# <table id="T_7409e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7409e_level0_col0" class="col_heading level0 col0" >REER</th>
#       <th id="T_7409e_level0_col1" class="col_heading level0 col1" >GDP</th>
#       <th id="T_7409e_level0_col2" class="col_heading level0 col2" >GDP Non-Oil</th>
#       <th id="T_7409e_level0_col3" class="col_heading level0 col3" >GDP Oil</th>
#       <th id="T_7409e_level0_col4" class="col_heading level0 col4" >CPI</th>
#       <th id="T_7409e_level0_col5" class="col_heading level0 col5" >OPEC</th>
#       <th id="T_7409e_level0_col6" class="col_heading level0 col6" >Exports</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7409e_level0_row0" class="row_heading level0 row0" >REER</th>
#       <td id="T_7409e_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_7409e_row0_col1" class="data row0 col1" >0.24</td>
#       <td id="T_7409e_row0_col2" class="data row0 col2" >0.88</td>
#       <td id="T_7409e_row0_col3" class="data row0 col3" >-0.57</td>
#       <td id="T_7409e_row0_col4" class="data row0 col4" >0.86</td>
#       <td id="T_7409e_row0_col5" class="data row0 col5" >-0.80</td>
#       <td id="T_7409e_row0_col6" class="data row0 col6" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_7409e_level0_row1" class="row_heading level0 row1" >GDP</th>
#       <td id="T_7409e_row1_col0" class="data row1 col0" >0.24</td>
#       <td id="T_7409e_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_7409e_row1_col2" class="data row1 col2" >0.59</td>
#       <td id="T_7409e_row1_col3" class="data row1 col3" >0.61</td>
#       <td id="T_7409e_row1_col4" class="data row1 col4" >0.60</td>
#       <td id="T_7409e_row1_col5" class="data row1 col5" >0.32</td>
#       <td id="T_7409e_row1_col6" class="data row1 col6" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_7409e_level0_row2" class="row_heading level0 row2" >GDP Non-Oil</th>
#       <td id="T_7409e_row2_col0" class="data row2 col0" >0.88</td>
#       <td id="T_7409e_row2_col1" class="data row2 col1" >0.59</td>
#       <td id="T_7409e_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_7409e_row2_col3" class="data row2 col3" >-0.26</td>
#       <td id="T_7409e_row2_col4" class="data row2 col4" >0.94</td>
#       <td id="T_7409e_row2_col5" class="data row2 col5" >-0.54</td>
#       <td id="T_7409e_row2_col6" class="data row2 col6" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_7409e_level0_row3" class="row_heading level0 row3" >GDP Oil</th>
#       <td id="T_7409e_row3_col0" class="data row3 col0" >-0.57</td>
#       <td id="T_7409e_row3_col1" class="data row3 col1" >0.61</td>
#       <td id="T_7409e_row3_col2" class="data row3 col2" >-0.26</td>
#       <td id="T_7409e_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_7409e_row3_col4" class="data row3 col4" >-0.22</td>
#       <td id="T_7409e_row3_col5" class="data row3 col5" >0.93</td>
#       <td id="T_7409e_row3_col6" class="data row3 col6" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_7409e_level0_row4" class="row_heading level0 row4" >CPI</th>
#       <td id="T_7409e_row4_col0" class="data row4 col0" >0.86</td>
#       <td id="T_7409e_row4_col1" class="data row4 col1" >0.60</td>
#       <td id="T_7409e_row4_col2" class="data row4 col2" >0.94</td>
#       <td id="T_7409e_row4_col3" class="data row4 col3" >-0.22</td>
#       <td id="T_7409e_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_7409e_row4_col5" class="data row4 col5" >-0.49</td>
#       <td id="T_7409e_row4_col6" class="data row4 col6" >0.54</td>
#     </tr>
#     <tr>
#       <th id="T_7409e_level0_row5" class="row_heading level0 row5" >OPEC</th>
#       <td id="T_7409e_row5_col0" class="data row5 col0" >-0.80</td>
#       <td id="T_7409e_row5_col1" class="data row5 col1" >0.32</td>
#       <td id="T_7409e_row5_col2" class="data row5 col2" >-0.54</td>
#       <td id="T_7409e_row5_col3" class="data row5 col3" >0.93</td>
#       <td id="T_7409e_row5_col4" class="data row5 col4" >-0.49</td>
#       <td id="T_7409e_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_7409e_row5_col6" class="data row5 col6" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_7409e_level0_row6" class="row_heading level0 row6" >Exports</th>
#       <td id="T_7409e_row6_col0" class="data row6 col0" >0.50</td>
#       <td id="T_7409e_row6_col1" class="data row6 col1" >0.62</td>
#       <td id="T_7409e_row6_col2" class="data row6 col2" >0.62</td>
#       <td id="T_7409e_row6_col3" class="data row6 col3" >0.19</td>
#       <td id="T_7409e_row6_col4" class="data row6 col4" >0.54</td>
#       <td id="T_7409e_row6_col5" class="data row6 col5" >-0.11</td>
#       <td id="T_7409e_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
varz['log_GDP'] = np.log(varz['GDP'])
varz['log_Non_oil_GDP'] = np.log(varz['GDP Non-Oil'])
varz['log_Oil_GDP'] = np.log(varz['GDP Oil'])
varz['log_REER'] = np.log(varz['REER'])
varz['log_CPI'] = np.log(varz['CPI'])
varz['log_OPEC'] = np.log(varz['OPEC'])
varz['log_Exports'] = np.log(varz['Exports'])

varz['dlog_GDP'] = varz['log_GDP'].diff()
varz['dlog_Non_oil_GDP'] = varz['log_Non_oil_GDP'].diff()
varz['dlog_Oil_GDP'] = varz['log_Oil_GDP'].diff()
varz['dlog_REER'] = varz['log_REER'].diff()
varz['dlog_CPI'] = varz['log_CPI'].diff()
varz['dlog_OPEC'] = varz['log_OPEC'].diff()
varz['dlog_Exports'] = varz['log_Exports'].diff()

varz = varz.drop(0, axis=0)

varz.head()

# %%
varz_ds['log_GDP'] = np.log(varz_ds['GDP'])
varz_ds['log_Non_oil_GDP'] = np.log(varz_ds['GDP Non-Oil'])
varz_ds['log_Oil_GDP'] = np.log(varz_ds['GDP Oil'])
varz_ds['log_REER'] = np.log(varz_ds['REER'])
varz_ds['log_CPI'] = np.log(varz_ds['CPI'])
varz_ds['log_OPEC'] = np.log(varz_ds['OPEC'])
varz_ds['log_Exports'] = np.log(varz_ds['Exports'])

varz_ds['dlog_GDP'] = varz_ds['log_GDP'].diff()
varz_ds['dlog_Non_oil_GDP'] = varz_ds['log_Non_oil_GDP'].diff()
varz_ds['dlog_Oil_GDP'] = varz_ds['log_Oil_GDP'].diff()
varz_ds['dlog_REER'] = varz_ds['log_REER'].diff()
varz_ds['dlog_CPI'] = varz_ds['log_CPI'].diff()
varz_ds['dlog_OPEC'] = varz_ds['log_OPEC'].diff()
varz_ds['dlog_Exports'] = varz_ds['log_Exports'].diff()

varz_ds = varz_ds.drop(0, axis=0)

varz_ds.head()
# Out:
#   Quarter            GDP    GDP Non-Oil        GDP Oil       REER        CPI  \
# 1  2010Q2  638209.329087  273623.489461  278404.643673  88.136985  82.075866
# 2  2010Q3  632283.555277  268249.783939  274238.791330  87.349167  83.255991
# 3  2010Q4  703164.885657  260063.266943  324926.391289  84.850417  84.627201
# 4  2011Q1  760945.974482  293294.082992  366466.844880  85.270097  86.467279
# 5  2011Q2  799515.561814  297099.540262  395689.693438  83.286985  87.362036
#
#          OPEC        Exports    log_GDP  log_Non_oil_GDP  ...   log_CPI  \
# 1  100.753092  242658.369411  13.366422        12.519508  ...  4.407644
# 2   96.458066  248071.761158  13.357093        12.499674  ...  4.421920
# 3  110.177765  257814.627504  13.463347        12.468680  ...  4.438256
# 4  128.519963  254690.841927  13.542318        12.588931  ...  4.459766
# 5  139.318089  262463.269411  13.591761        12.601823  ...  4.470061
#
#    log_OPEC  log_Exports  dlog_GDP  dlog_Non_oil_GDP  dlog_Oil_GDP  dlog_REER  \
# 1  4.612673    12.399410 -0.015570          0.010591     -0.008639   0.037299
# 2  4.569108    12.421473 -0.009328         -0.019834     -0.015076  -0.008979
# 3  4.702095    12.459996  0.106253         -0.030994      0.169599  -0.029024
# 4  4.856084    12.447806  0.078971          0.120251      0.120309   0.004934
# 5  4.936760    12.477866  0.049444          0.012891      0.076722  -0.023532
#
#    dlog_CPI  dlog_OPEC  dlog_Exports
# 1  0.015578  -0.018007      0.039238
# 2  0.014276  -0.043565      0.022063
# 3  0.016336   0.132987      0.038523
# 4  0.021510   0.153989     -0.012190
# 5  0.010295   0.080675      0.030061
#
# [5 rows x 22 columns]

# %%
varz_ds.tail()
# Out:
#    Quarter           GDP    GDP Non-Oil        GDP Oil        REER  \
# 50  2022Q3  1.087525e+06  456806.323588  426998.130480  103.402501
# 51  2022Q4  1.035324e+06  473288.506370  356406.497475  104.527084
# 52  2023Q1  1.016472e+06  464066.505479  338102.389772  101.126763
# 53  2023Q2  9.789345e+05  471059.653733  301200.471111  101.970319
# 54  2023Q3  9.981683e+05  466422.591600  315572.137573  102.149167
#
#            CPI        OPEC        Exports    log_GDP  log_Non_oil_GDP  ...  \
# 50  107.377594  103.312952  329040.761158  13.899415        13.032015  ...
# 51  108.389393   90.208948  312188.127504  13.850225        13.067460  ...
# 52  108.648612   81.517897  318832.141927  13.831848        13.047783  ...
# 53  109.541067   76.601390  317247.969411  13.794220        13.062740  ...
# 54  109.510927   87.155900  275334.861158  13.813677        13.052847  ...
#
#      log_CPI  log_OPEC  log_Exports  dlog_GDP  dlog_Non_oil_GDP  dlog_Oil_GDP  \
# 50  4.676352  4.637763    12.703937 -0.028282          0.035557     -0.111878
# 51  4.685730  4.502129    12.651361 -0.049190          0.035446     -0.180708
# 52  4.688119  4.400823    12.672420 -0.018377         -0.019677     -0.052723
# 53  4.696300  4.338615    12.667439 -0.037628          0.014957     -0.115573
# 54  4.696024  4.467698    12.525743  0.019457         -0.009893      0.046611
#
#     dlog_REER  dlog_CPI  dlog_OPEC  dlog_Exports
# 50   0.026315  0.007008  -0.100883      0.036840
# 51   0.010817  0.009379  -0.135634     -0.052576
# 52  -0.033071  0.002389  -0.101306      0.021059
# 53   0.008307  0.008181  -0.062207     -0.004981
# 54   0.001752 -0.000275   0.129083     -0.141696
#
# [5 rows x 22 columns]

# %%
def adf_test(series, name):
    result = adfuller(series)
    print(f'ADF Test for {name}')
    print(f'p-value: {result[1]}')
    
# Exports are I(0) 
adf_test(varz_ds['log_GDP'], 'log GDP')
adf_test(varz_ds['log_Non_oil_GDP'], 'log Non-oil GDP')
adf_test(varz_ds['log_REER'], 'log REER')
adf_test(varz_ds['log_CPI'], 'log CPI')
adf_test(varz_ds['log_OPEC'], 'log OPEC Basket Price')
adf_test(varz_ds['log_Exports'], 'log Exports')
# Out:
# ADF Test for log GDP
# p-value: 0.34271179148584174
# ADF Test for log Non-oil GDP
# p-value: 0.6917599454647636
# ADF Test for log REER
# p-value: 0.5793356650016118
# ADF Test for log CPI
# p-value: 0.42173497387941067
# ADF Test for log OPEC Basket Price
# p-value: 0.40299314137945436
# ADF Test for log Exports
# p-value: 0.0004345647855202614

# %%
varz_ds.to_csv('metrics_data2.csv', index=False)

# %% [markdown]
# Adding Non-oil and Oil Exports. This reduces the sample size

# %%
exports = pd.read_csv('exports_r.csv')

# %%
exports['Date'] = pd.to_datetime(exports['Date'], format='%Y / %m')
exports.set_index('Date', inplace=True)
exports= exports.resample('QE').sum()
exports = exports.reset_index()
exports['Quarter'] = exports['Date'].dt.to_period('Q')
exports.head()
# Out:
# /var/folders/cz/t_24t6f16nj00hrh5mf4s5jh0000gn/T/ipykernel_52490/2294934999.py:3: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   exports= exports.resample('Q').sum()
#         Date  Total Exports   Oil Exports  Non-oil Exports Quarter
# 0 2015-03-31   192849.70485  145116.05921      47733.64565  2015Q1
# 1 2015-06-30   220661.94570  172703.50772      47958.43800  2015Q2
# 2 2015-09-30   184956.45927  138794.18878      46162.27048  2015Q3
# 3 2015-12-31   164844.95270  116934.80679      47910.14591  2015Q4
# 4 2016-03-31   140185.63677   97158.41141      43027.22536  2016Q1

# %% [markdown]
# 'Total Exports': exports['Total Exports'], 'Oil Exports': exports['Oil Exports'],
#                             'Non-Oil Exports': exports['Non-oil Exports']

# %%
varz = pd.DataFrame(data = { 'Quarter': reer['Quarter'], 'REER': reer["REER"], "GDP": core_data['Gross Domestic Product'], 'GDP Non-Oil' : core_data['GDP Non-Oil Activities'],
                            'GDP Oil': core_data['GDP Oil Activities'], 'CPI': core_data['CPI'],
                            'OPEC' : q_opec['Oil_Price']})
varz2 = pd.merge(varz, exports, on='Quarter')
varz2 = varz2.drop(labels = 'Date', axis=1)
varz2.head()
# Out:
#   Quarter        REER        GDP  GDP Non-Oil    GDP Oil        CPI  \
# 0  2015Q1   97.290000  654710.35    347095.72  163823.38  95.960000
# 1  2015Q2   97.493333  652337.08    334515.58  192997.26  96.236667
# 2  2015Q3   99.210000  619818.18    338921.32  159034.10  96.576667
# 3  2015Q4  100.500000  583700.82    336757.86  136359.71  96.950000
# 4  2016Q1  102.646667  594201.06    354955.37  109462.65  98.420000
#
#         OPEC  Total Exports   Oil Exports  Non-oil Exports
# 0  50.273810   192849.70485  145116.05921      47733.64565
# 1  59.895000   220661.94570  172703.50772      47958.43800
# 2  48.291061   184956.45927  138794.18878      46162.27048
# 3  39.706615   164844.95270  116934.80679      47910.14591
# 4  30.159219   140185.63677   97158.41141      43027.22536

# %%
varz2['GDP'] = 109.501439 * varz2['GDP'] / varz2['CPI']
varz2['GDP Non-Oil'] = 109.501439 * varz2['GDP Non-Oil'] / varz2['CPI']
varz2['GDP Oil'] = 109.501439 * varz2['GDP Oil'] / varz2['CPI']
varz2['OPEC'] = 109.501439 * varz2['OPEC'] / varz2['CPI']
varz2['Total Exports'] = 109.501439 * varz2['Total Exports'] / varz2['CPI']
varz2['Oil Exports'] = 109.501439 * varz2['Oil Exports'] / varz2['CPI']
varz2['Non-oil Exports'] = 109.501439 * varz2['Non-oil Exports'] / varz2['CPI']
varz2.head()
# Out:
#   Quarter        REER            GDP    GDP Non-Oil        GDP Oil        CPI  \
# 0  2015Q1   97.290000  747100.098512  396076.290233  186941.390703  95.960000
# 1  2015Q2   97.493333  742251.902988  380623.505005  219599.020044  96.236667
# 2  2015Q3   99.210000  702767.914534  384278.869083  180317.496974  96.576667
# 3  2015Q4  100.500000  659268.486183  380355.546824  154013.248753  96.950000
# 4  2016Q1  102.646667  661104.156933  394920.989593  121787.418124  98.420000
#
#         OPEC  Total Exports    Oil Exports  Non-oil Exports
# 0  57.368221  220063.778572  165594.177840     54469.600744
# 1  68.150622  251076.865220  196508.080237     54568.785006
# 2  54.753812  209709.023315  157368.895824     52340.127480
# 3  44.847153  186186.276767  132073.539069     54112.737698
# 4  33.554947  155969.609362  108097.803905     47871.805457

# %%
dfcorr1 = varz2.drop('Quarter', axis=1).corr()
dfcorr1.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_12b94_row0_col0, #T_12b94_row1_col1, #T_12b94_row2_col2, #T_12b94_row3_col3, #T_12b94_row4_col4, #T_12b94_row5_col5, #T_12b94_row6_col6, #T_12b94_row6_col7, #T_12b94_row7_col6, #T_12b94_row7_col7, #T_12b94_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_12b94_row0_col1, #T_12b94_row0_col2, #T_12b94_row0_col3, #T_12b94_row0_col4, #T_12b94_row0_col5, #T_12b94_row0_col6, #T_12b94_row0_col7, #T_12b94_row0_col8, #T_12b94_row8_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col3, #T_12b94_row3_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_12b94_row1_col5 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col6 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col7 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_12b94_row1_col8, #T_12b94_row5_col8, #T_12b94_row6_col8, #T_12b94_row8_col5 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_12b94_row2_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_12b94_row2_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_12b94_row2_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_12b94_row2_col4, #T_12b94_row4_col6 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_12b94_row2_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_12b94_row2_col6 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_12b94_row2_col7 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_12b94_row2_col8 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_12b94_row3_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_12b94_row3_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_12b94_row3_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_12b94_row3_col5, #T_12b94_row5_col7, #T_12b94_row7_col5 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_12b94_row3_col6, #T_12b94_row6_col5 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_12b94_row3_col7, #T_12b94_row5_col6, #T_12b94_row6_col3, #T_12b94_row7_col3 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_12b94_row3_col8 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_12b94_row4_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_12b94_row4_col1, #T_12b94_row4_col8 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_12b94_row4_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_12b94_row4_col3 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_12b94_row4_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_12b94_row4_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_12b94_row5_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_12b94_row5_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_12b94_row5_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_12b94_row5_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_12b94_row5_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_12b94_row6_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_12b94_row6_col1 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_12b94_row6_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_12b94_row6_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_12b94_row7_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_12b94_row7_col1 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_12b94_row7_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_12b94_row7_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_12b94_row7_col8 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_12b94_row8_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_12b94_row8_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_12b94_row8_col3 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_12b94_row8_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_12b94_row8_col6 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_12b94_row8_col7 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_12b94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12b94_level0_col0" class="col_heading level0 col0" >REER</th>
#       <th id="T_12b94_level0_col1" class="col_heading level0 col1" >GDP</th>
#       <th id="T_12b94_level0_col2" class="col_heading level0 col2" >GDP Non-Oil</th>
#       <th id="T_12b94_level0_col3" class="col_heading level0 col3" >GDP Oil</th>
#       <th id="T_12b94_level0_col4" class="col_heading level0 col4" >CPI</th>
#       <th id="T_12b94_level0_col5" class="col_heading level0 col5" >OPEC</th>
#       <th id="T_12b94_level0_col6" class="col_heading level0 col6" >Total Exports</th>
#       <th id="T_12b94_level0_col7" class="col_heading level0 col7" >Oil Exports</th>
#       <th id="T_12b94_level0_col8" class="col_heading level0 col8" >Non-oil Exports</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12b94_level0_row0" class="row_heading level0 row0" >REER</th>
#       <td id="T_12b94_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_12b94_row0_col1" class="data row0 col1" >0.17</td>
#       <td id="T_12b94_row0_col2" class="data row0 col2" >0.32</td>
#       <td id="T_12b94_row0_col3" class="data row0 col3" >0.13</td>
#       <td id="T_12b94_row0_col4" class="data row0 col4" >0.46</td>
#       <td id="T_12b94_row0_col5" class="data row0 col5" >0.01</td>
#       <td id="T_12b94_row0_col6" class="data row0 col6" >0.06</td>
#       <td id="T_12b94_row0_col7" class="data row0 col7" >0.06</td>
#       <td id="T_12b94_row0_col8" class="data row0 col8" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_12b94_level0_row1" class="row_heading level0 row1" >GDP</th>
#       <td id="T_12b94_row1_col0" class="data row1 col0" >0.17</td>
#       <td id="T_12b94_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_12b94_row1_col2" class="data row1 col2" >0.86</td>
#       <td id="T_12b94_row1_col3" class="data row1 col3" >0.96</td>
#       <td id="T_12b94_row1_col4" class="data row1 col4" >0.75</td>
#       <td id="T_12b94_row1_col5" class="data row1 col5" >0.94</td>
#       <td id="T_12b94_row1_col6" class="data row1 col6" >0.93</td>
#       <td id="T_12b94_row1_col7" class="data row1 col7" >0.92</td>
#       <td id="T_12b94_row1_col8" class="data row1 col8" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_12b94_level0_row2" class="row_heading level0 row2" >GDP Non-Oil</th>
#       <td id="T_12b94_row2_col0" class="data row2 col0" >0.32</td>
#       <td id="T_12b94_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_12b94_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_12b94_row2_col3" class="data row2 col3" >0.74</td>
#       <td id="T_12b94_row2_col4" class="data row2 col4" >0.75</td>
#       <td id="T_12b94_row2_col5" class="data row2 col5" >0.71</td>
#       <td id="T_12b94_row2_col6" class="data row2 col6" >0.70</td>
#       <td id="T_12b94_row2_col7" class="data row2 col7" >0.69</td>
#       <td id="T_12b94_row2_col8" class="data row2 col8" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_12b94_level0_row3" class="row_heading level0 row3" >GDP Oil</th>
#       <td id="T_12b94_row3_col0" class="data row3 col0" >0.13</td>
#       <td id="T_12b94_row3_col1" class="data row3 col1" >0.96</td>
#       <td id="T_12b94_row3_col2" class="data row3 col2" >0.74</td>
#       <td id="T_12b94_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_12b94_row3_col4" class="data row3 col4" >0.62</td>
#       <td id="T_12b94_row3_col5" class="data row3 col5" >0.97</td>
#       <td id="T_12b94_row3_col6" class="data row3 col6" >0.98</td>
#       <td id="T_12b94_row3_col7" class="data row3 col7" >0.98</td>
#       <td id="T_12b94_row3_col8" class="data row3 col8" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_12b94_level0_row4" class="row_heading level0 row4" >CPI</th>
#       <td id="T_12b94_row4_col0" class="data row4

# %%
varz2['log_GDP'] = np.log(varz2['GDP'])
varz2['log_Non_oil_GDP'] = np.log(varz2['GDP Non-Oil'])
varz2['log_Oil_GDP'] = np.log(varz2['GDP Oil'])
varz2['log_REER'] = np.log(varz2['REER'])
varz2['log_CPI'] = np.log(varz2['CPI'])
varz2['log_OPEC'] = np.log(varz2['OPEC'])
varz2['log_Total_Exports'] = np.log(varz2['Total Exports'])
varz2['log_Oil_Exports'] = np.log(varz2['Oil Exports'])
varz2['log_Non_oil_Exports'] = np.log(varz2['Non-oil Exports'])

varz2['dlog_GDP'] = varz2['log_GDP'].diff()
varz2['dlog_Non_oil_GDP'] = varz2['log_Non_oil_GDP'].diff()
varz2['dlog_Oil_GDP'] = varz2['log_Oil_GDP'].diff()
varz2['dlog_REER'] = varz2['log_REER'].diff()
varz2['dlog_CPI'] = varz2['log_CPI'].diff()
varz2['dlog_OPEC'] = varz2['log_OPEC'].diff()
varz2['dlog_Total_Exports'] = varz2['log_Total_Exports'].diff()
varz2['dlog_Oil_Exports'] = varz2['log_Oil_Exports'].diff()
varz2['dlog_Non_oil_Exports'] = varz2['log_Non_oil_Exports'].diff()

varz2 = varz2.drop(0,axis=0)
varz2.head()
# Out:
#   Quarter        REER        GDP  GDP Non-Oil    GDP Oil        CPI  \
# 0  2015Q1   97.290000  654710.35    347095.72  163823.38  95.960000
# 1  2015Q2   97.493333  652337.08    334515.58  192997.26  96.236667
# 2  2015Q3   99.210000  619818.18    338921.32  159034.10  96.576667
# 3  2015Q4  100.500000  583700.82    336757.86  136359.71  96.950000
# 4  2016Q1  102.646667  594201.06    354955.37  109462.65  98.420000
#
#         OPEC  Total Exports   Oil Exports  Non-oil Exports  ...  \
# 0  50.273810   192849.70485  145116.05921      47733.64565  ...
# 1  59.895000   220661.94570  172703.50772      47958.43800  ...
# 2  48.291061   184956.45927  138794.18878      46162.27048  ...
# 3  39.706615   164844.95270  116934.80679      47910.14591  ...
# 4  30.159219   140185.63677   97158.41141      43027.22536  ...
#
#    log_Non_oil_Exports  dlog_GDP  dlog_Non_oil_GDP  dlog_Oil_GDP  dlog_REER  \
# 0            10.773392       NaN               NaN           NaN        NaN
# 1            10.778090 -0.003632         -0.036917      0.163887   0.002088
# 2            10.739918 -0.051135          0.013085     -0.193557   0.017455
# 3            10.777083 -0.060038         -0.006404     -0.153822   0.012919
# 4            10.669588  0.017829          0.052628     -0.219713   0.021135
#
#    dlog_CPI  dlog_OPEC  dlog_Total_Exports  dlog_Oil_Exports  \
# 0       NaN        NaN                 NaN               NaN
# 1  0.002879   0.175109            0.134721          0.174042
# 2  0.003527  -0.215347           -0.176511         -0.218584
# 3  0.003858  -0.195729           -0.115115         -0.171376
# 4  0.015049  -0.275027           -0.162038         -0.185274
#
#    dlog_Non_oil_Exports
# 0                   NaN
# 1              0.004698
# 2             -0.038172
# 3              0.037164
# 4             -0.107494
#
# [5 rows x 28 columns]

# %%
def adf_test(series, name):
    result = adfuller(series)
    print(f'ADF Test for {name}')
    print(f'p-value: {result[1]}')
    

adf_test(varz2['log_GDP'], 'log GDP')
adf_test(varz2['log_Non_oil_GDP'], 'log Non-oil GDP')
adf_test(varz2['log_REER'], 'log REER')
adf_test(varz2['log_CPI'], 'log CPI')
adf_test(varz2['log_OPEC'], 'log OPEC Basket Price')
adf_test(varz2['log_Non_oil_Exports'], 'log Non-oil Exports')
# Out:
# ADF Test for log GDP
# p-value: 0.8427522365222927
# ADF Test for log Non-oil GDP
# p-value: 0.9572193275465566
# ADF Test for log REER
# p-value: 0.3922375815766411
# ADF Test for log CPI
# p-value: 0.9394330173502607
# ADF Test for log OPEC Basket Price
# p-value: 0.48645346853966814
# ADF Test for log Non-oil Exports
# p-value: 0.9906428363462889

# %% [markdown]
# Bounds test for Cointegration

# %%
dloggdp_order = ardl_select_order(endog = varz2['dlog_GDP'], 
                                  exog = varz2[['dlog_OPEC', 'dlog_CPI', 'dlog_REER']], 
                                  maxlag=4, maxorder=4)

print(dloggdp_order.ar_lags)
print(dloggdp_order.dl_lags)
# Out:
# [1, 2, 3, 4]
# {'dlog_OPEC': [0, 1, 2], 'dlog_CPI': [0, 1, 2, 3, 4]}

# %%
gdp_ardl = ARDL(endog= varz2['dlog_GDP'], lags= 4, exog= varz2[['dlog_OPEC', 'dlog_CPI', 'log_OPEC', 'log_CPI']],
                order= {'dlog_OPEC': 2, 'dlog_CPI': 4, 'log_OPEC': 1, 'log_CPI': 1}, causal= False, trend= 'c')

gdp_ardl_results = gdp_ardl.fit()
gdp_ardl_results.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 4
#       1 gdp_ardl = ARDL(endog= varz2['dlog_GDP'], lags= 4, exog= varz2[['dlog_OPEC', 'dlog_CPI', 'log_OPEC', 'log_CPI']],
#       2                 order= {'dlog_OPEC': 2, 'dlog_CPI': 4, 'log_OPEC': 1, 'log_CPI': 1}, causal= False, trend= 'c')
# ----> 4 gdp_ardl_results = gdp_ardl.fit(exog_oos=False)
#       5 gdp_ardl_results.summary()
#
# TypeError: ARDL.fit() got an unexpected keyword argument 'exog_oos'

# %%
varz2.to_csv('metric_data.csv',index=False)

# %%
dlogoilgdp_order = ardl_select_order(endog = varz2['GDP'], 
                                  exog = varz2[['OPEC', 'CPI']], 
                                  maxlag=0, maxorder=0)

print(dlogoilgdp_order.ar_lags)
print(dlogoilgdp_order.dl_lags)
# Out:
# None
# {'OPEC': [0], 'CPI': [0]}

# %%
dlogoilgdp_order.model.fit().summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 dlogoilgdp_order.model.fit().summary()
#
# File ~/Desktop/Oil Price Volatility Project/myvenv/lib/python3.12/site-packages/statsmodels/tsa/ardl/model.py:1297, in ARDLResults.summary(self, alpha)
#    1283 dep_name = str(self.model.endog_names)
#    1284 top_left = [
#    1285     ("Dep. Variable:", [dep_name]),
#    1286     ("Model:", [model]),
#    (...)
#    1291     ("", [sample[1]]),
#    1292 ]
#    1294 top_right = [
#    1295     ("No. Observations:", [str(len(self.model.endog))]),
#    1296     ("Log Likelihood", ["%#5.3f" % self.llf]),
# -> 1297     ("S.D. of innovations", ["%#5.3f" % self.sigma2**0.5]),
#    1298     ("AIC", ["%#5.3f" % self.aic]),
#    1299     ("BIC", ["%#5.3f" % self.bic]),
#    1300     ("HQIC", ["%#5.3f" % self.hqic]),
#    1301 ]
#    1303 smry = Summary()
#    1304 smry.add_table_2cols(
#    1305     self, gleft=top_left, gright=top_right, title=title
#    1306 )
#
# File ~/Desktop/Oil Price Volatility Project/myvenv/lib/python3.12/site-packages/statsmodels/tools/decorators.py:95, in CachedAttribute.__get__(self, obj, type)
#      93 _cachedval = _cache.get(name, None)
#      94 if _cachedval is None:
# ---> 95     _cachedval = self.fget(obj)
#      96     _cache[name] = _cachedval
#      98 return _cachedval
#
# File ~/Desktop/Oil Price Volatility Project/myvenv/lib/python3.12/site-packages/statsmodels/tsa/ar_model.py:1034, in AutoRegResults.sigma2(self)
#    1032 @cache_writable()
#    1033 def sigma2(self):
# -> 1034     return 1.0 / self.nobs * sumofsq(self.resid)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Desktop/Oil Price Volatility Project/myvenv/lib/python3.12/site-packages/statsmodels/tsa/ar_model.py:1125, in AutoRegResults.resid(self)
#    1123 model = self.model
#    1124 endog = model.endog.squeeze()
# -> 1125 return endog[self._hold_back :] - self.fittedvalues
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Desktop/Oil Price Volatility Project/myvenv/lib/python3.12/site-packages/statsmodels/tsa/ar_model.py:1178, in AutoRegResults.fittedvalues(self)
#    1170 @cache_readonly
#    1171 def fittedvalues(self):
#    1172     """
#    1173     The in-sample predicted values of the fitted AR model.
#    1174
#    1175     The `k_ar` initial values are computed via the Kalman Filter if the
#    1176     model is fit by `mle`.
#    1177     """
# -> 1178     return self.model.predict(self.params)[self._hold_back :]
#
# File ~/Desktop/Oil Price Volatility Project/myvenv/lib/python3.12/site-packages/statsmodels/tsa/ardl/model.py:801, in ARDL.predict(self, params, start, end, dynamic, exog, exog_oos, fixed, fixed_oos)
#     799 if num_oos > max_1step:
#     800     if self._order and exog_oos is None:
# --> 801         raise ValueError(
#     802             "exog_oos must be provided when out-of-sample "
#     803             "observations require values of the exog not in the "
#     804             "original sample"
#     805         )
#     806     elif self._order and (exog_oos.shape[0] + max_1step) < num_oos:
#     807         raise ValueError(
#     808             f"exog_oos must have at least {num_oos - max_1step} "
#     809             f"observations to produce {num_oos} forecasts based on "
#     810             "the model specification."
#     811         )
#
# ValueError: exog_oos must be provided when out-of-sample observations require values of the exog not in the original sample
